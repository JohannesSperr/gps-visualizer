# %%
import os
import time
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import mplleaflet
from selenium import webdriver

# %%
def filter_gps(data):
    pass

# %%
def calculate_distance(data):
    pass

# %% [markdown]
# ### Read GPS data

# %%
data = pd.read_csv('data.csv', delimiter=';')
#data = filter_gps(data)   
#distance = calculate_distance(data)

data.head(5)
# Out:
#          lon        lat
# 0  13.315017  52.500836
# 1  13.315902  52.500977
# 2  13.316771  52.501114
# 3  13.318241  52.501336
# 4  13.319426  52.501522

# %% [markdown]
# ### Visualize GPS in Open Street Map

# %%
plt.plot(data['lon'], data['lat'], linewidth=7, c='royalblue') # Draw blue line
plt.scatter(data['lon'], data['lat'], s=400, c='royalblue') # Draw gps points

# Load open street map in browser and plot gps data
mplleaflet.show()

# %% [markdown]
# ### Safe map as image

# %%
# Save an image of the displayed map
browser = webdriver.Firefox()
map_url ='file:///C:/Users/johan/jupyter_notebooks/gps-visualizer/_map.html'.format(path=os.getcwd(),mapfile=map)
browser.get(map_url)
delay = 5
time.sleep(delay)
browser.save_screenshot('map.png')
browser.quit()

# Import the saved image again
img = mpimg.imread('C:/Users/johan/jupyter_notebooks/gps-visualizer/map.png')
plt.rcParams["figure.figsize"] = [20,30]
imgplot = plt.imshow(img)
